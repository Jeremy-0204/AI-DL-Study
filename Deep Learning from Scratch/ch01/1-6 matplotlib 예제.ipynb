# %% [markdown]
# ### 1.6 Matplotlib
#
# #### 1.6.1 단순한 그래프 그리기
#
# pyplot 모듈을 이용한다.

# %%
import numpy as np
import matplotlib.pyplot as plt

# 데이터 준비
x = np.arange(0, 6, 0.1) # 0에서 6까지 0.1 간격으로 생성
y = np.sin(x)

# 그래프 그리기
plt.plot(x, y)
plt.show()

# %% [markdown]
# #### 1.6.2 pyplot의 기능
#
# 제목과 각 축의 이름 (레이블) 표시등의 다른 기능을 활용할 수 있다.

# %%
y2 = np.cos(x)

# 그래프 그리기
plt.plot(x, y, label = "sin")
plt.plot(x, y2, linestyle="--", label = "cos")
plt.xlabel("x") # x축 이름
plt.ylabel("y") # y축 이름
plt.title('sin & cos') # 제목
plt.legend() # 좌측 하단에 그래프별 점선 정보
plt.show()

# %% [markdown]
# #### 1.6.3 이미지 표시하기
#
# pyplot의imshow()와 matplotlib.image 모듈의 imread() 메서드를 이용한다.

# %%
from matplotlib.image import imread

img = imread("C:\Users\parkk\OneDrive\사진\Screenshots\스크린샷_20230131_103725.jpg")

plt.imshow(img)
plt.show()
# Out:
#   File "<ipython-input-6-c3b497f014f5>", line 3
#     img = imread("C:\Users\parkk\OneDrive\사진\Screenshots\스크린샷_20230131_103725.jpg")
#                 ^
# SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 2-3: truncated \UXXXXXXXX escape
